# %%
import sys
sys.path.append('../')

from src.m4_generator import M4Generator
from src.m4_data_loader import M4DataLoader
from src.m4_evaluation_loss_functions import *
from src.visualization import *
from src.evaluation import *
from src.m4_model import M4Model
from glob import glob

import numpy as np
import keras
import matplotlib.pyplot as plt

import tensorflow as tf

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
MODEL_BASE_DIR = '../models/kl_divergance'
TRAIN_PATH = "../Dataset/splitted/Hourly-train.csv"
TEST_PATH = "../Dataset/splitted/Hourly-test.csv"
TRAIN_HOLDOUT_PATH = "../Dataset/splitted/Hourly-train-holdout.csv"
TEST_HOLDOUT_PATH= "../Dataset/splitted/Hourly-test-holdout.csv"

stdAugmentation = StdAugmentation()
x_augmentations = [stdAugmentation]
y_augmentations = [stdAugmentation]

loss_functions = [m4_mase]
models_arch = ['1-LSTM', '2-LSTM', '3-LSTM']
# Out:
# Missing PI Params

# %% [markdown]
# # Full Evaluation And Comparsion ( Point Prediction)
# Evaluate all trained models aginst all error functions

# %%
data = {'Model':[], 'Training Loss Function':[], 'Epochs':[], 'LOOKBACK': [], 'Hidden Layer Size':[],
        'Features Number':[], 'T-MASE': [], 'T-MASE Naive': [], 'H-MASE': [], 'H-MASE Naive': [],
        'T-Imporvement %': [],'H-Imporvement %': [], 
       }

for model_arc in models_arch:
    s = f'{MODEL_BASE_DIR}/{model_arc}/*/'
    models = glob(s)
    for model_path in models:
        ev_results = {}
        
        for loss in loss_functions:
            ev_results = load_and_evaluate_model(model_path, TRAIN_PATH, TEST_PATH, 
                                                 TRAIN_HOLDOUT_PATH, TEST_HOLDOUT_PATH,
                                                 x_augmentations, y_augmentations, loss)
        data['Model'].append(model_arc)
        data['Training Loss Function'].append(ev_results['hyperparameters']['loss'])
        data['Epochs'].append(ev_results['hyperparameters']['epochs'])
        data['LOOKBACK'].append(ev_results['hyperparameters']['lookback'])
        data['Hidden Layer Size'].append(ev_results['hyperparameters']['hidden_layer_size'])
        data['Features Number'].append(ev_results['hyperparameters']['features_number'])
        data['T-MASE'].append(ev_results['test_error'])
        data['T-MASE Naive'].append(ev_results['naive_test_error'])
        data['H-MASE'].append(ev_results['holdout_error'])
        data['H-MASE Naive'].append(ev_results['naive_holdout_error'])
        
        test_naive_improv = (ev_results["naive_test_error"]- ev_results["test_error"])*100/ev_results["naive_test_error"]
        #test_snaive_improv = (ev_results["snaive_test_error"]- ev_results["test_error"])*100/ev_results["snaive_test_error"]

        holdout_naive_improv = (ev_results["naive_holdout_error"]- ev_results["holdout_error"])*100/ev_results["naive_holdout_error"]
        #holdout_snaive_improv = (ev_results["snaive_holdout_error"]- ev_results["holdout_error"])*100/ev_results["snaive_test_error"]
        
        data['T-Imporvement %'].append(round(test_naive_improv,3))
        
        #data['Test Imporvement sNaive %'].append(round(test_snaive_improv,3))
        data['H-Imporvement %'].append(round(holdout_naive_improv, 3))
        #data['holdout Imporvement sNaive %'].append(round(holdout_snaive_improv,3))

df = pd.DataFrame(data=data)

dfStyler = df.style.set_properties(**{'text-align': 'center'})
dfStyler.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
# Out:
# Loaded model from disk
# Loaded model from disk
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# <style  type="text/css" >
#     #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79 th {
#           text-align: center;
#     }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col0 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col1 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col2 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col3 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col4 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col5 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col6 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col7 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col8 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col9 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col10 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row0_col11 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row1_col0 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row1_col1 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row1_col2 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row1_col3 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row1_col4 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row1_col5 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row1_col6 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row1_col7 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row1_col8 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_11ea_9ccd_8c85902c1a79row6_col8 {
#             text-align:  center;
#         }    #T_e5fabc1a_354f_

# %%
df.to_csv('../models/kl_divergance/comparsion_point_predection.csv', sep='\t')

# %% [markdown]
# # Full Evaluation And Comparsion ( Intervals Prediction Test)

# %%
data = {'Model':[], 'Training Loss Function':[], 'Epochs':[], 'LOOKBACK': [], 'Hidden Layer Size':[],
        'Features Number':[], 'ACD': [], 'ACD Naive': [], 'MSIS': [], 'MSIS Naive': [],
        'ACD-Imporvement %': [],'MSIS-Imporvement %': [], 
       }

for model_arc in models_arch:
    s = f'{MODEL_BASE_DIR}/{model_arc}/*/'
    models = glob(s)
    for model_path in models:
        
        ev_results = {}
        
        for loss in loss_functions:
            ev_results = load_and_evaluate_model_PI(model_path, TRAIN_PATH, TEST_PATH, 
                                                 TRAIN_HOLDOUT_PATH, TEST_HOLDOUT_PATH,
                                                 x_augmentations, y_augmentations, evaluate_kl_PI)
        data['Model'].append(model_arc)
        data['Training Loss Function'].append(ev_results['hyperparameters']['loss'])
        data['Epochs'].append(ev_results['hyperparameters']['epochs'])
        data['LOOKBACK'].append(ev_results['hyperparameters']['lookback'])
        data['Hidden Layer Size'].append(ev_results['hyperparameters']['hidden_layer_size'])
        data['Features Number'].append(ev_results['hyperparameters']['features_number'])
        data['ACD'].append(ev_results['acd_test'])
        data['ACD Naive'].append(ev_results['acd_naive_test'])
        data['MSIS'].append(ev_results['msis_test'])
        data['MSIS Naive'].append(ev_results['msis_naive_test'])
        
        acd_naive_improv = (ev_results["acd_naive_test"]- ev_results["acd_test"])*100/ev_results["acd_naive_test"]

        msis_naive_improv = (ev_results["msis_naive_test"]- ev_results["msis_test"])*100/ev_results["msis_naive_test"]
        
        data['ACD-Imporvement %'].append(round(acd_naive_improv,3))
        data['MSIS-Imporvement %'].append(round(msis_naive_improv, 3))

df = pd.DataFrame(data=data)

dfStyler = df.style.set_properties(**{'text-align': 'center'})
dfStyler.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
# Out:
# Loaded model from disk
# Loaded model from disk
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# <style  type="text/css" >
#     #T_8068590a_3551_11ea_8987_8c85902c1a79 th {
#           text-align: center;
#     }    #T_8068590a_3551_11ea_8987_8c85902c1a79row0_col0 {
#             text-align:  center;
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row5_col7 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row5_col8 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row5_col9 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row5_col10 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row5_col11 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row6_col0 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row6_col1 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row6_col2 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row6_col3 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row6_col4 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row6_col5 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row6_col6 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row6_col7 {
#             text-align:  center;
#         }    #T_8068590a_3551_11ea_8987_8c85902c1a79row6_col8 {
#             text-align:  center;
#         }    #T_8068590a_3551_

# %%
df.to_csv('../models/kl_divergance/comparsion_pi_test.csv', sep='\t')

# %% [markdown]
# # Full Evaluation And Comparsion ( Intervals Prediction holdout)

# %%
data = {'Model':[], 'Training Loss Function':[], 'Epochs':[], 'LOOKBACK': [], 'Hidden Layer Size':[],
        'Features Number':[], 'ACD': [], 'ACD Naive': [], 'MSIS': [], 'MSIS Naive': [],
        'ACD-Imporvement %': [],'MSIS-Imporvement %': [], 
       }

for model_arc in models_arch:
    s = f'{MODEL_BASE_DIR}/{model_arc}/*/'
    models = glob(s)
    for model_path in models:
        
        ev_results = {}
        
        for loss in loss_functions:
            ev_results = load_and_evaluate_model_PI(model_path, TRAIN_PATH, TEST_PATH, 
                                                 TRAIN_HOLDOUT_PATH, TEST_HOLDOUT_PATH,
                                                 x_augmentations, y_augmentations, evaluate_kl_PI)
        data['Model'].append(model_arc)
        data['Training Loss Function'].append(ev_results['hyperparameters']['loss'])
        data['Epochs'].append(ev_results['hyperparameters']['epochs'])
        data['LOOKBACK'].append(ev_results['hyperparameters']['lookback'])
        data['Hidden Layer Size'].append(ev_results['hyperparameters']['hidden_layer_size'])
        data['Features Number'].append(ev_results['hyperparameters']['features_number'])
        data['ACD'].append(ev_results['acd_holdout'])
        data['ACD Naive'].append(ev_results['acd_naive_holdout'])
        data['MSIS'].append(ev_results['msis_holdout'])
        data['MSIS Naive'].append(ev_results['msis_naive_holdout'])
        
        acd_naive_improv = (ev_results["acd_naive_holdout"]- ev_results["acd_holdout"])*100/ev_results["acd_naive_holdout"]

        msis_naive_improv = (ev_results["msis_naive_holdout"]- ev_results["msis_holdout"])*100/ev_results["msis_naive_holdout"]
        
        data['ACD-Imporvement %'].append(round(acd_naive_improv,3))
        data['MSIS-Imporvement %'].append(round(msis_naive_improv, 3))

df = pd.DataFrame(data=data)

dfStyler = df.style.set_properties(**{'text-align': 'center'})
dfStyler.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
# Out:
# Loaded model from disk
# Loaded model from disk
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# Loaded model from disk
# Missing key'learning_rate'
# <style  type="text/css" >
#     #T_a972ea4a_3551_11ea_8987_8c85902c1a79 th {
#           text-align: center;
#     }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col0 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col1 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col2 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col3 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col4 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col5 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col6 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col7 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col8 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col9 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col10 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row0_col11 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row1_col0 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row1_col1 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row1_col2 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row1_col3 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row1_col4 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row1_col5 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row1_col6 {
#             text-align:  center;
#         }    #T_a972ea4a_3551_11ea_8987_8c85902c1a79row1_col7 {
